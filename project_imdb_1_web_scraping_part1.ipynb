# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def status_check(url):
    import requests
    r=requests.get(url)
    if r.status_code<300:
        print("request was successful")
    elif r.status_code>=400 and r.status_code<500:
        print('request failed because it is non-existant or forbidden')
    else: print('blablabla')
    return r

# %%
def get_html(url):
    r=status_check(url)
    html = BeautifulSoup(r.text, 'html.parser')
    return html

# %%
url_pattern='https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2020-12-31&user_rating=1.0,10.0&sort=num_votes,desc&count=250&start={}'

# %% [markdown]
# ## looping all pages

# %% [markdown]
# there are 96560 titles total, 250 titles per page
# but after 10000, it goes back to the first page, so we can only get 10000 movies

# %%
pages = np.arange(1, 10000, 250)

# %%
titles = []
imdbIDs = []
years = []
certificates = []
genres = []
runtimes = []
ratings = []
metascores = []
directors = []
votes = []
grossings = []

for page in pages:
    print(page)
    url = url_pattern.format(page)
    page_html = get_html(url)
    movie_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')
    
    for container in movie_containers:
        
        #imdbID
        ID = container.a['href']
        imdbIDs.append(ID)
    
        #title
        title = container.h3.a.text
        titles.append(title)

        #year
        year = container.h3.find('span', class_= 'lister-item-year').text
        years.append(year)

        #certificate
        if container.p.find('span', class_="certificate") is not None:
            certif = container.p.find('span', class_="certificate").text
            certificates.append(certif)
        else:
            certificates.append(None)

        #genre
        if container.p.find('span', class_ = 'genre') is not None:
            genre = container.p.find('span', class_ = 'genre').text
            genres.append(genre)
        else:
            genres.append(None)

        #runtime
        if container.p.find('span', class_ = 'runtime') is not None:
            runtime = container.p.find('span', class_ = 'runtime').text
            runtimes.append(runtime)
        else:
            runtimes.append(None)

        #rating
        if container.strong is not None:
            rating = float(container.strong.text)
            ratings.append(rating)
        else:
            ratings.append(None)

        #metascore
        if container.find('span', class_ = 'metascore') is not None:
            score= int(container.find('span', class_ = 'metascore').text)
            metascores.append(score)
        else:
            metascores.append(None)

        #director
        if len(container.select('p:contains("Director")>a:first-child'))>0:
            director= container.select('p:contains("Director")>a:first-child')[0].text
            directors.append(director)    
        else:
            directors.append(None)

        #number of votes
        if len(container.select('span:contains("Votes")+span'))>0:
            vote = container.select('span:contains("Votes")+span')[0].text
            votes.append(vote)
        else:
            votes.append(None)

        #gross
        if len(container.select('span:contains("Gross")+span'))>0:
            gross = container.select('span:contains("Gross")+span')[0].text
            grossings.append(gross)
        else:
            grossings.append(None)
            
    time.sleep(2)
# Out:
# 1
# request was successful
# 251
# request was successful
# 501
# request was successful
# 751
# request was successful
# 1001
# request was successful
# 1251
# request was successful
# 1501
# request was successful
# 1751
# request was successful
# 2001
# request was successful
# 2251
# request was successful
# 2501
# request was successful
# 2751
# request was successful
# 3001
# request was successful
# 3251
# request was successful
# 3501
# request was successful
# 3751
# request was successful
# 4001
# request was successful
# 4251
# request was successful
# 4501
# request was successful
# 4751
# request was successful
# 5001
# request was successful
# 5251
# request was successful
# 5501
# request was successful
# 5751
# request was successful
# 6001
# request was successful
# 6251
# request was successful
# 6501
# request was successful
# 6751
# request was successful
# 7001
# request was successful
# 7251
# request was successful
# 7501
# request was successful
# 7751
# request was successful
# 8001
# request was successful
# 8251
# request was successful
# 8501
# request was successful
# 8751
# request was successful
# 9001
# request was successful
# 9251
# request was successful
# 9501
# request was successful
# 9751
# request was successful
# 10001
# request was successful
# 10251
# request was successful
# 10501
# request was successful
# 10751
# request was successful
# 11001
# request was successful
# 11251
# request was successful
# 11501
# request was successful
# 11751
# request was successful
# 12001
# request was successful
# 12251
# request was successful
# 12501
# request was successful
# 12751
# request was successful
# 13001
# request was successful
# 13251
# request was successful
# 13501
# request was successful
# 13751
# request was successful
# 14001
# request was successful
# 14251
# request was successful
# 14501
# request was successful
# 14751
# request was successful
# 15001
# request was successful
# 15251
# request was successful
# 15501
# request was successful
# 15751
# request was successful
# 16001
# request was successful
# 16251
# request was successful
# 16501
# request was successful
# 16751
# request was successful
# 17001
# request was successful
# 17251
# request was successful
# 17501
# request was successful
# 17751
# request was successful
# 18001
# request was successful
# 18251
# request was successful
# 18501
# request was successful
# 18751
# request was successful
# 19001
# request was successful
# 19251
# request was successful
# 19501
# request was successful
# 19751
# request was successful
# 20001
# request was successful
# 20251
# request was successful
# 20501
# request was successful
# 20751
# request was successful
# 21001
# request was successful
# 21251
# request was successful
# 21501
# request was successful
# 21751
# request was successful
# 22001
# request was successful
# 22251
# request was successful
# 22501
# request was successful
# 22751
# request was successful
# 23001
# request was successful
# 23251
# request was successful
# 23501
# request was successful
# 23751
# request was successful
# 24001
# request was successful
# 24251
# request was successful
# 24501
# request was successful
# 24751
# request was successful
# 25001
# request was successful
# 25251
# request was successful
# 25501
# request was successful
# 25751
# request was successful
# 26001
# request was successful
# 26251
# request was successful
# 26501
# request was successful
# 26751
# request was successful
# 27001
# request was successful
# 27251
# request was successful
# 27501
# request was successful
# 27751
# request was successful
# 28001
# request was successful
# 28251
# request was successful
# 28501
# request was successful
# 28751
# request was successful
# 29001
# request was successful
# 29251
# request was successful
# 29501
# request was successful
# 29751
# request was successful
# 30001
# request was successful
# 30251
# request was successful
# 30501
# request was successful
# 30751
# request was successful
# 31001
# request was successful
# 31251
# request was successful
# 31501
# request was successful
# 31751
# request was successful
# 32001
# request was successful
# 32251
# request was successful
# 32501
# request was successful
# 32751
# request was successful
# 33001
# request was successful
# 33251
# request was successful
# 33501
# request was successful
# 33751
# request was successful
# 34001
# request was successful
# 34251
# request was successful
# 34501
# request was successful
# 34751
# request was successful
# 35001
# request was successful
# 35251
# request was successful
# 35501
# request was successful
# 35751
# request was successful
# 36001
# request was successful
# 36251
# request was successful
# 36501
# request was successful
# 36751
# request was successful
# 37001
# request was successful
# 37251
# request was successful
# 37501
# request was successful
# 37751
# request was successful
# 38001
# request was successful
# 38251
# request was successful
# 38501
# request was successful
# 38751
# request was successful
# 39001
# request was successful
# 39251
# request was successful
# 39501
# request was successful
# 39751
# request was successful
# 40001
# request was successful
# 40251
# request was successful
# 40501
# request was successful
# 40751
# request was successful
# 41001
# request was successful
# 41251
# request was successful
# 41501
# request was successful
# 41751
# request was successful
# 42001
# request was successful
# 42251
# request was successful
# 42501
# request was successful
# 42751
# request was successful
# 43001
# request was successful
# 43251
# request was successful
# 43501
# request was successful
# 43751
# request was successful
# 44001
# request was successful
# 44251
# request was successful
# 44501
# request was successful
# 44751
# request was successful
# 45001
# request was successful
# 45251
# request was successful
# 45501
# request was successful
# 45751
# request was successful
# 46001
# request was successful
# 46251
# request was successful
# 46501
# request was successful
# 46751
# request was successful
# 47001
# request was successful
# 47251
# request was successful
# 47501
# request was successful
# 47751
# request was successful
# 48001
# request was successful
# 48251
# request was successful
# 48501
# request was successful
# 48751
# request was successful
# 49001
# request was successful
# 49251
# request was successful
# 49501
# request was successful
# 49751
# request was successful
# 50001
# request was successful
# 50251
# request was successful
# 50501
# request was successful
# 50751
# request was successful
# 51001
# request was successful
# 51251
# request was successful
# 51501
# request was successful
# 51751
# request was successful
# 52001
# request was successful
# 52251
# request was successful
# 52501
# request was successful
# 52751
# request was successful
# 53001
# request was successful
# 53251
# request was successful
# 53501
# request was successful
# 53751
# request was successful
# 54001
# request was successful
# 54251
# request was successful
# 54501
# request was successful
# 54751
# request was successful
# 55001
# request was successful
# 55251
# request was successful
# 55501
# request was successful
# 55751
# request was successful
# 56001
# request was successful
# 56251
# request was successful
# 56501
# request was successful
# 56751
# request was successful
# 57001
# request was successful
# 57251
# request was successful
# 57501
# request was successful
# 57751
# request was successful
# 58001
# request was successful
# 58251
# request was successful
# 58501
# request was successful
# 58751
# request was successful
# 59001
# request was successful
# 59251
# request was successful
# 59501
# request was successful
# 59751
# request was successful
# 60001
# request was successful
# 60251
# request was successful
# 60501
# request was successful
# 60751
# request was successful
# 61001
# request was successful
# 61251
# request was successful
# 61501
# request was successful
# 61751
# request was successful
# 62001
# request was successful
# 62251
# request was successful
# 62501
# request was successful
# 62751
# request was successful
# 63001
# request was successful
# 63251
# request was successful
# 63501
# request was successful
# 63751
# request was successful
# 64001
# request was successful
# 64251
# request was successful
# 64501
# request was successful
# 64751
# request was successful
# 65001
# request was successful
# 65251
# request was successful
# 65501
# request was successful
# 65751
# request was successful
# 66001
# request was successful
# 66251
# request was successful
# 66501
# request was successful
# 66751
# request was successful
# 67001
# request was successful
# 67251
# request was successful
# 67501
# request was successful
# 67751
# request was successful
# 68001
# request was successful
# 68251
# request was successful
# 68501
# request was successful
# 68751
# request was successful
# 69001
# request was successful
# 69251
# request was successful
# 69501
# request was successful
# 69751
# request was successful
# 70001
# request was successful
# 70251
# request was successful
# 70501
# request was successful
# 70751
# request was successful
# 71001
# request was successful
# 71251
# request was successful
# 71501
# request was successful
# 71751
# request was successful
# 72001
# request was successful
# 72251
# request was successful
# 72501
# request was successful
# 72751
# request was successful
# 73001
# request was successful
# 73251
# request was successful
# 73501
# request was successful
# 73751
# request was successful
# 74001
# request was successful
# 74251
# request was successful
# 74501
# request was successful
# 74751
# request was successful
# 75001
# request was successful
# 75251
# request was successful
# 75501
# request was successful
# 75751
# request was successful
# 76001
# request was successful
# 76251
# request was successful
# 76501
# request was successful
# 76751
# request was successful
# 77001
# request was successful
# 77251
# request was successful
# 77501
# request was successful
# 77751
# request was successful
# 78001
# request was successful
# 78251
# request was successful
# 78501
# request was successful
# 78751
# request was successful
# 79001
# request was successful
# 79251
# request was successful
# 79501
# request was successful
# 79751
# request was successful
# 80001
# request was successful
# 80251
# request was successful
# 80501
# request was successful
# 80751
# request was successful
# 81001
# request was successful
# 81251
# request was successful
# 81501
# request was successful
# 81751
# request was successful
# 82001
# request was successful
# 82251
# request was successful
# 82501
# request was successful
# 82751
# request was successful
# 83001
# request was successful
# 83251
# request was successful
# 83501
# request was successful
# 83751
# request was successful
# 84001
# request was successful
# 84251
# request was successful
# 84501
# request was successful
# 84751
# request was successful
# 85001
# request was successful
# 85251
# request was successful
# 85501
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11004] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x0000000014D2BC18>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /search/title/?title_type=feature&release_date=2000-01-01,2020-12-31&user_rating=1.0,10.0&sort=num_votes,desc&count=250&start=85501 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000000014D2BC18>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-33-888d53db1656> in <module>
#      14     print(page)
#      15     url = url_pattern.format(page)
# ---> 16     page_html = get_html(url)
#      17     movie_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')
#      18
#
# <ipython-input-3-123e1614b5ea> in get_html(url)
#       1 def get_html(url):
# ----> 2     r=status_check(url)
#       3     html = BeautifulSoup(r.text, 'html.parser')
#       4     return html
#
# <ipython-input-2-84341731ecb1> in status_check(url)
#       1 def status_check(url):
#       2     import requests
# ----> 3     r=requests.get(url)
#       4     if r.status_code<300:
#       5         print("request was successful")
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.imdb.com', port=443): Max retries exceeded with url: /search/title/?title_type=feature&release_date=2000-01-01,2020-12-31&user_rating=1.0,10.0&sort=num_votes,desc&count=250&start=85501 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000000014D2BC18>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed'))

# %%
df = pd.DataFrame({'movie': titles,
                       'year': years,
                       'imdbID': imdbIDs,
                       'certificate': certificates,
                       'genre': genres,
                       'runtime': runtimes,
                       'rating': ratings,
                       'metascore': metascores,
                       'director': directors,
                       'votes': votes,
                      'gross':grossings})

# %%
df.head()
# Out:
#                                                movie    year  \
# 0                 The Dark Knight: Le chevalier noir  (2008)
# 1                                          Inception  (2010)
# 2  Le seigneur des anneaux: La communauté de l'an...  (2001)
# 3          Le seigneur des anneaux: Le retour du roi  (2003)
# 4                              The Dark Knight Rises  (2012)
#
#               imdbID   certificate                                    genre  \
# 0  /title/tt0468569/  Tous publics       \nAction, Crime, Drama
# 1  /title/tt1375666/  Tous publics  \nAction, Adventure, Sci-Fi
# 2  /title/tt0120737/  Tous publics  \nAdventure, Drama, Fantasy
# 3  /title/tt0167260/  Tous publics  \nAdventure, Drama, Fantasy
# 4  /title/tt1345836/  Tous publics           \nAction, Thriller
#
#    runtime  rating  metascore           director      votes     gross
# 0  152 min     9.0       84.0  Christopher Nolan  2,161,024  $534.86M
# 1  148 min     8.8       74.0  Christopher Nolan  1,909,234  $292.58M
# 2  178 min     8.8       92.0      Peter Jackson  1,561,138  $315.54M
# 3  201 min     8.9       94.0      Peter Jackson  1,549,252  $377.85M
# 4  164 min     8.4       78.0  Christopher Nolan  1,431,808  $448.14M

# %%
df.to_csv('movies_imdb_messy.csv', index=False)
